# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavbollu/Bhargavbollu/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-08 07:37:47--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  91.1MB/s    in 0.8s
#
# 2024-04-08 07:37:49 (91.1 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3231   1502.01094v2  Dictionary learning algorithms have been succe...  stat
# 38335  1608.04917v2  We study the cohesion within and the coalition...    cs
# 40089  1710.06647v3  Inverse problems appear in many applications s...    cs
# 27408  1703.05868v3  Understanding traffic density from large-scale...    cs
# 28099  1705.06712v1  Accurate and reliable segmentation of catheter...    cs
# ...             ...                                                ...   ...
# 37358  1704.08119v1  We propose a development of the Analytic Hiera...    cs
# 7768   1803.02517v1  In many real-world applications, data is not c...  stat
# 16284  1611.04953v2  Sentence ordering is one of important tasks in...    cs
# 17181  1709.02828v1  Rapid progress has been made towards question ...    cs
# 35899   1304.7920v1  We show how, and under which conditions, the e...  stat
#
#                                                    title  year  \
# 3231   Multimodal Task-Driven Dictionary Learning for...  2015
# 38335  Cohesion and Coalition Formation in the Europe...  2016
# 40089  Image Restoration by Iterative Denoising and B...  2017
# 27408  Understanding Traffic Density from Large-Scale...  2017
# 28099    Model-based Catheter Segmentation in MRI-images  2017
# ...                                                  ...   ...
# 37358  Using a new parsimonious AHP methodology combi...  2017
# 7768   Sequential Maximum Margin Classifiers for Part...  2018
# 16284  End-to-End Neural Sentence Ordering Using Poin...  2016
# 17181                         Globally Normalized Reader  2017
# 35899  From Ordinary Differential Equations to Struct...  2013
#
#                                                 keywords
# 3231   [dictionary, algorithms, successfully, reconst...
# 38335  [coalitions, political, parliament, analyzing,...
# 40089  [applications, deblurring, inpainting, algorit...
# 27408  [understanding, challenging, resolution, occlu...
# 28099  [segmentation, catheters, interventions, chall...
# ...                                                  ...
# 37358  [development, hierarchy, permitting, methodolo...
# 7768   [applications, collected, sequentially, desira...
# 16284  [important, improving, performance, nontrivial...
# 17181  [answering, approaches, expensive, directional...
# 35899  [conditions, equilibrium, differential, descri...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3231     [dictionary, algorithms, successfully, reconst...
# 38335    [coalitions, political, parliament, analyzing,...
# 40089    [applications, deblurring, inpainting, algorit...
# 27408    [understanding, challenging, resolution, occlu...
# 28099    [segmentation, catheters, interventions, chall...
#                                ...
# 21136    [behaviour, recognition, information, commerci...
# 6423     [privileged, relationship, individual, implici...
# 20814    [communication, information, communicated, rep...
# 5725     [classifiers, distributed, classifier, approxi...
# 35335    [framework, verification, specifications, exec...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8709 words.
# Out of those 4611 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f1b7546f-01ec-4e8a-921f-07deb59d50f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1b7546f-01ec-4e8a-921f-07deb59d50f5")) {                    Plotly.newPlot(                        "f1b7546f-01ec-4e8a-921f-07deb59d50f5",                        [{"x":["optimized","applications","discriminative","dictionary","collaborations","information","resulting","efficient","algorithms","dictionaries","demonstrated","scenarios","performance","recognition","formulation","algorithm","modalities","constraint","successfully","simultaneously","advantages","biometric","represented","reconstructive","extension","different","corresponding","classification","counterpart","classifiers","developed","illustrated","formulations","representation","multiclass","multimodal","independent","combination","facilitates","computationally","relationship","formation","analyzing","processes","reliability","perspective","exponential","corresponds","activities","agreement","methodologies","political","coalition","retweeting","interesting","completely","coalitions","introduced","framework","restoration","techniques","inpainting","projections","demonstrate","alternative","competitive","theoretical","iterative","capabilities","parameter","impressive","denoising","burdensome","empirically","deblurring","leveraging","challenges","arbitrary","understanding","collected","individual","convolution","estimates","occlusion","extensively","significantly","regression","understand","optimization","detection","prediction","challenging","constrained","perspectives","containing","evaluated","resolution","importance","reasonable","heuristics","segmentation","candidate","workflows","constrain","assumptions","estimated","mechanical","sequences","trajectories","including","searching","segmented","challenge","deviating","interventions","characteristics","identification","reduction","management","automatic","originate","interested","multipath","appearing","probabilities","explosion","exploited","introduces","assignment","measurement","combinatorial","computational","simulation","estimation","measurements","intractable","variational","correspondence","numerical","association","probabilistic","posterior","incorporates","approximate","generates","traditional","maintenance","variables","calculates","propagation","automatically","effectively","termination","effective","reconstructed","comparably","statements","predictions","assistant","efficiently","selection","evaluation","accessible","popularity","experiments","isabellehol","dependencies","accordingly","transforms","processed","adaptation","reasoning","automated","convolutional","regularized","establish","unsupervised","unlabeled","supervised","temporally","assumption","semantically","connection","compensation","resonance","significant","transform","integrated","reconstructions","effectiveness","intensity","canonical","initialization","arbitrarily","qualitative","pipelines","requirement","approximately","synthetic","quantitatively"],"y":[47,436,82,34,2,710,153,400,617,17,102,98,866,389,85,818,29,78,89,108,89,13,76,0,56,758,159,498,9,107,212,21,25,359,12,26,119,142,15,95,60,27,68,100,34,62,40,25,29,21,11,6,3,1,72,39,2,122,542,13,382,13,21,590,99,132,146,75,47,119,18,46,2,81,8,52,120,98,151,84,123,49,79,28,38,267,122,68,306,329,226,250,51,22,60,155,115,88,23,40,220,57,1,14,56,84,17,101,28,243,25,32,174,2,6,97,108,105,50,199,3,25,2,9,54,10,37,79,25,35,35,270,85,203,57,31,52,31,70,24,170,47,34,115,51,164,8,112,6,81,164,111,5,242,21,11,19,80,9,138,155,280,10,20,557,2,44,17,19,24,64,140,88,405,42,41,146,51,222,20,77,28,47,4,24,212,50,65,9,223,27,24,19,15,71,12,32,39,143,25],"type":"bar"},{"x":["optimized","applications","discriminative ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4611,), (4611, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8141666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Markov</span> <span style=''>Random</span> <span style=''>Walk</span> <span style='background-color:rgba(0, 255, 0, 0.3097345132743363);'>Representations</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Continuous</span> <span style='background-color:rgba(255, 0, 0, 0.3260869565217391);'>Distributions</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3097345132743363);'>Representations</span> <span style=''>based</span> <span style=''>on</span> <span style=''>random</span> <span style=''>walks</span> <span style=''>can</span> <span style=''>exploit</span> <span style=''>discrete</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3260869565217391);'>distributions</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>We</span> <span style=''>extend</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3097345132743363);'>representations</span> <span style=''>from</span> <span style=''>discrete</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style='background-color:rgba(255, 0, 0, 0.3260869565217391);'>distributions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Transition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>are</span> <span style=''>now</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>calculated</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diffusion</span> <span style=''>equation</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diffusion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coefficient</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666667);'>inversely</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>the</span> <span style=''>data</span> <span style=''>density</span> <span style=''>We</span> <span style=''>relate</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diffusion</span> <span style=''>equation</span> <span style=''>to</span> <span style=''>a</span> <span style=''>path</span> <span style=''>integral</span> <span style=''>and</span> <span style=''>derive</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>path</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>measure</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>is</span> <span style=''>useful</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.6315789473684209);'>densities</span> <span style=''>and</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.39805825242718457);'>knowledge</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictive</span> <span style=''>Coarse</span> <span style=''>Graining</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>data</span> <span style=''>driven</span> <span style=''>coarse</span> <span style=''>graining</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equilibrium</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanics</span> <span style=''>In</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>which</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>fine</span> <span style=''>to</span> <span style=''>coarse</span> <span style=''>map</span> <span style=''>we</span> <span style=''>adopt</span> <span style=''>the</span> <span style=''>opposite</span> <span style=''>strategy</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prescribing</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>coarse</span> <span style=''>to</span> <span style=''>fine</span> <span style=''>map</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponds</span> <span style=''>to</span> <span style=''>a</span> <span style=''>directed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>where</span> <span style=''>the</span> <span style=''>coarse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>play</span> <span style=''>the</span> <span style=''>role</span> <span style=''>of</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generators</span> <span style=''>of</span> <span style=''>the</span> <span style=''>fine</span> <span style=''>scale</span> <span style=''>(all</span> <span style=''>atom)</span> <span style=''>data</span> <span style=''>From</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>proposed</span> <span style=''>provides</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvement</span> <span style=''>upon</span> <span style=''>the</span> <span style=''>relative</span> <span style=''>entropy</span> <span style=''>method</span> <span style=''>and</span> <span style=''>is</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantifying</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>loss</span> <span style=''>that</span> <span style=''>unavoidably</span> <span style=''>takes</span> <span style=''>place</span> <span style=''>during</span> <span style=''>the</span> <span style=''>CG</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style=''>readily</span> <span style=''>extended</span> <span style=''>to</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Bayesian</span> <span style=''>Sampling</span> <span style=''>Approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exploration</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.4333333333333333);'>Reinforcement</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>modular</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.4333333333333333);'>reinforcement</span> <span style=''>learning</span> <span style=''>that</span> <span style=''>uses</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.34456928838951323);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>over</span> <span style=''>models</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>BOSS</span> <span style=''>(Best</span> <span style=''>of</span> <span style=''>Sampled</span> <span style=''>Set)</span> <span style=''>drives</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploration</span> <span style=''>by</span> <span style=''>sampling</span> <span style=''>multiple</span> <span style=''>models</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5436893203883495);'>posterior</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selecting</span> <span style=''>actions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimistically</span> <span style=''>It</span> <span style=''>extends</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>providing</span> <span style=''>a</span> <span style=''>rule</span> <span style=''>for</span> <span style=''>deciding</span> <span style=''>when</span> <span style=''>to</span> <span style=''>resample</span> <span style=''>and</span> <span style=''>how</span> <span style=''>to</span> <span style=''>combine</span> <span style=''>the</span> <span style=''>models</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>achieves</span> <span style=''>nearoptimal</span> <span style=''>reward</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>with</span> <span style=''>a</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>that</span> <span style=''>is</span> <span style=''>low</span> <span style=''>relative</span> <span style=''>to</span> <span style=''>the</span> <span style=''>speed</span> <span style=''>at</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5436893203883495);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>distribution</span> <span style='background-color:rgba(255, 0, 0, 0.3580246913580246);'>converges</span> <span style=''>during</span> <span style=''>learning</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>BOSS</span> <span style=''>performs</span> <span style=''>quite</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>favorably</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.4333333333333333);'>reinforcement</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structured</span> <span style=''>Boosting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Connections</span> <span style=''>Between</span> <span style=''>Gradient</span> <span style=''>Boosted</span> <span style=''>Stumps</span> <span style=''>and</span> <span style=''>Full</span> <span style=''>Decision</span> <span style=''>Trees</span> <br/><br/><span style=''>Additive</span> <span style=''>models</span> <span style=''>such</span> <span style=''>as</span> <span style=''>produced</span> <span style=''>by</span> <span style=''>gradient</span> <span style=''>boosting</span> <span style=''>and</span> <span style=''>full</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>models</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>trees</span> <span style=''>(CART)</span> <span style=''>are</span> <span style=''>widely</span> <span style=''>used</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigated</span> <span style=''>largely</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>isolation</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>these</span> <span style=''>models</span> <span style=''>exist</span> <span style=''>along</span> <span style=''>a</span> <span style=''>spectrum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>revealing</span> <span style=''>never</span> <span style=''>before</span> <span style=''>known</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connections</span> <span style=''>between</span> <span style=''>these</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>called</span> <span style=''>tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>boosting</span> <span style=''>for</span> <span style=''>creating</span> <span style=''>a</span> <span style=''>single</span> <span style=''>decision</span> <span style=''>tree</span> <span style=''>and</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>this</span> <span style=''>method</span> <span style=''>can</span> <span style=''>produce</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>CART</span> <span style=''>or</span> <span style=''>gradient</span> <span style=''>boosted</span> <span style=''>stumps</span> <span style=''>at</span> <span style=''>the</span> <span style=''>extremes</span> <span style=''>by</span> <span style=''>varying</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>Although</span> <span style=''>tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>boosting</span> <span style=''>is</span> <span style=''>designed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>primarily</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>both</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>and</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.10071942446043165)
# 	processing (0.10503597122302158)
# 	knowledge (0.12949640287769784)
# 	experimental (0.13848920863309352)
# 	information (0.25539568345323743)
# 	segmentation (0.07913669064748201)
# 	detection (0.11834532374100719)
# 	different (0.27266187050359714)
# 	recognition (0.13992805755395685)
# 	convolutional (0.14568345323741008)
#
# Some Statistics words are:
# 	statistical (0.14603960396039603)
# 	algorithm (0.38712871287128714)
# 	stochastic (0.13465346534653466)
# 	estimation (0.16881188118811882)
# 	variables (0.13712871287128714)
# 	theoretical (0.16287128712871288)
# 	dimensional (0.18465346534653465)
# 	inference (0.200990099009901)
# 	distribution (0.1910891089108911)
# 	regression (0.1797029702970297)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a87dc69b-2ef1-4e98-b7f5-48abe1efc86b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a87dc69b-2ef1-4e98-b7f5-48abe1efc86b")) {                    Plotly.newPlot(                        "a87dc69b-2ef1-4e98-b7f5-48abe1efc86b",                        [{"x":["optimized","applications","discriminative","dictionary","collaborations","information","resulting","efficient","algorithms","dictionaries","demonstrated","scenarios","performance","recognition","formulation","algorithm","modalities","constraint","successfully","simultaneously","advantages","biometric","represented","reconstructive","extension","different","corresponding","classification","counterpart","classifiers","developed","illustrated","formulations","representation","multiclass","multimodal","independent","combination","facilitates","computationally","relationship","formation","analyzing","processes","reliability","perspective","exponential","corresponds","activities","agreement","methodologies","political","coalition","retweeting","interesting","completely","coalitions","introduced","framework","restoration","techniques","inpainting","projections","demonstrate","alternative","competitive","theoretical","iterative","capabilities","parameter","impressive","denoising","burdensome","empirically","deblurring","leveraging","challenges","arbitrary","understanding","collected","individual","convolution","estimates","occlusion","extensively","significantly","regression","understand","optimization","detection","prediction","challenging","constrained","perspectives","containing","evaluated","resolution","importance","reasonable","heuristics","segmentation","candidate","workflows","constrain","assumptions","estimated","mechanical","sequences","trajectories","including","searching","segmented","challenge","deviating","interventions","characteristics","identification","reduction","management","automatic","originate","interested","multipath","appearing","probabilities","explosion","exploited","introduces","assignment","measurement","combinatorial","computational","simulation","estimation","measurements","intractable","variational","correspondence","numerical","association","probabilistic","posterior","incorporates","approximate","generates","traditional","maintenance","variables","calculates","propagation","automatically","effectively","termination","effective","reconstructed","comparably","statements","predictions","assistant","efficiently","selection","evaluation","accessible","popularity","experiments","isabellehol","dependencies","accordingly","transforms","processed","adaptation","reasoning","automated","convolutional","regularized","establish","unsupervised","unlabeled","supervised","temporally","assumption","semantically","connection","compensation","resonance","significant","transform","integrated","reconstructions","effectiveness","intensity","canonical","initialization","arbitrarily","qualitative","pipelines","requirement","approximately","synthetic","quantitatively","qualitatively","simulated","transformations","registration","reconstruction","predicting","architecture","alignment","complicate","minimizing","viewpoint","probability","objective","identifiability","distributions","cumulants","comparison","polynomial","geometric","covariance","criterion","algebraic","involving","themselves","structures","synthesize","temporary","neocortex","postulate","dynamical","dynamically","formalized","modulation","topologically","principle","functions","homogeneous","attributes","resembling","associated","intuitively","manipulating","classical","questions","characteristic","computations","manipulates","representing","implementable","universal","imaginary","improving","distribut ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	reconstructive
# 	cumulants
# 	specialization
# 	replicable
# 	contaminated
# 	forecasters
# 	forecaster
# 	entropies
# 	borrowings
# 	simplemkl
# 	penalization
# 	hellinger
# 	semiparametric
# 	inferential
# 	depression
# 	projectorg
# 	sectional
# 	unverifiable
# 	misspecification
# 	microwave
# Some words which never appear in Statistics papers:
# 	coalition
# 	coalitions
# 	deblurring
# 	multipath
# 	termination
# 	assistant
# 	isabellehol
# 	resembling
# 	manipulating
# 	manipulates
# 	forensics
# 	steganalysis
# 	uniformity
# 	motivations
# 	segmentations
# 	endoscopic
# 	surrounded
# 	observers
# 	biologists
# 	withdrawn

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.085372250161982e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.77
